# %%
import pandas as pd

# %%
df_cust=pd.read_csv("resources/customer_data.csv")
df_cust
# Out:
#       label        id  fea_1   fea_2  fea_3     fea_4  fea_5  fea_6  fea_7  \
# 0         1  54982665      5  1245.5      3   77000.0      2     15      5
# 1         0  59004779      4  1277.0      1  113000.0      2      8     -1
# 2         0  58990862      7  1298.0      1  110000.0      2     11     -1
# 3         1  58995168      7  1335.5      1  151000.0      2     11      5
# 4         0  54987320      7     NaN      2   59000.0      2     11      5
# ...     ...       ...    ...     ...    ...       ...    ...    ...    ...
# 1120      0  58988196      5  1289.0      1  173000.0      2     15      5
# 1121      0  58987926      5     NaN      2   50000.0      2     15      5
# 1122      0  58995381      7  1220.0      3   76000.0      2     11      2
# 1123      0  58998054      4  1250.0      3  137000.0      2      8      5
# 1124      0  54989781      4  1415.0      3   93000.0      2      8      5
#
#       fea_8  fea_9  fea_10      fea_11
# ...

# %%
df_cust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1125 entries, 0 to 1124
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   label   1125 non-null   int64
#  1   id      1125 non-null   int64
#  2   fea_1   1125 non-null   int64
#  3   fea_2   976 non-null    float64
#  4   fea_3   1125 non-null   int64
#  5   fea_4   1125 non-null   float64
#  6   fea_5   1125 non-null   int64
#  7   fea_6   1125 non-null   int64
#  8   fea_7   1125 non-null   int64
#  9   fea_8   1125 non-null   int64
#  10  fea_9   1125 non-null   int64
#  11  fea_10  1125 non-null   int64
#  12  fea_11  1125 non-null   float64
# dtypes: float64(3), int64(10)
# memory usage: 114.4 KB

# %%
df_cust.isna().sum()
# Out:
# label       0
# id          0
# fea_1       0
# fea_2     149
# fea_3       0
# fea_4       0
# fea_5       0
# fea_6       0
# fea_7       0
# fea_8       0
# fea_9       0
# fea_10      0
# fea_11      0
# dtype: int64

# %%
df_cust.describe().T
# Out:
#          count          mean           std         min         25%  \
# label   1125.0  2.000000e-01  4.001779e-01         0.0         0.0
# id      1125.0  5.783677e+07  1.817150e+06  54982353.0  54990497.0
# fea_1   1125.0  5.482667e+00  1.383338e+00         1.0         4.0
# fea_2    976.0  1.283911e+03  5.176402e+01      1116.5      1244.0
# fea_3   1125.0  2.333333e+00  8.787730e-01         1.0         1.0
# fea_4   1125.0  1.208836e+05  8.844523e+04     15000.0     72000.0
# fea_5   1125.0  1.928889e+00  2.571247e-01         1.0         2.0
# fea_6   1125.0  1.087200e+01  2.676437e+00         3.0         8.0
# fea_7   1125.0  4.832889e+00  2.971182e+00        -1.0         5.0
# fea_8   1125.0  1.008027e+02  1.198896e+01        64.0        90.0
# fea_9   1125.0  4.195556e+00  8.556790e-01         1.0         3.0
# fea_10  1125.0  1.646185e+05  1.525205e+05     60000.0     60044.0
# fea_11  1125.0  1.349990e+02  1.126168e+02         1.0         1.0
#
# ...

# %%
df_cust["fea_2"].mean(), df_cust["fea_2"].median()
# Out:
# (1283.9113729508197, 1281.5)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_graph=pd.DataFrame({
    "Risk Düzeyi":df_cust["label"].value_counts().index,
    "Toplam Sayı":df_cust["label"].value_counts().values
})
plt.title("Risk Dağılımı")
sns.barplot(data=df_graph, x="Risk Düzeyi",y="Toplam Sayı")
# Out:
# <AxesSubplot:title={'center':'Risk Dağılımı'}, xlabel='Risk Düzeyi', ylabel='Toplam Sayı'>

# %%
df_cust["fea_2"].fillna(df_cust["fea_2"].mean(),inplace=True)
df_cust.isna().sum()
# Out:
# label     0
# id        0
# fea_1     0
# fea_2     0
# fea_3     0
# fea_4     0
# fea_5     0
# fea_6     0
# fea_7     0
# fea_8     0
# fea_9     0
# fea_10    0
# fea_11    0
# dtype: int64

# %%
df_cust
# Out:
#       label        id  fea_1        fea_2  fea_3     fea_4  fea_5  fea_6  \
# 0         1  54982665      5  1245.500000      3   77000.0      2     15
# 1         0  59004779      4  1277.000000      1  113000.0      2      8
# 2         0  58990862      7  1298.000000      1  110000.0      2     11
# 3         1  58995168      7  1335.500000      1  151000.0      2     11
# 4         0  54987320      7  1283.911373      2   59000.0      2     11
# ...     ...       ...    ...          ...    ...       ...    ...    ...
# 1120      0  58988196      5  1289.000000      1  173000.0      2     15
# 1121      0  58987926      5  1283.911373      2   50000.0      2     15
# 1122      0  58995381      7  1220.000000      3   76000.0      2     11
# 1123      0  58998054      4  1250.000000      3  137000.0      2      8
# 1124      0  54989781      4  1415.000000      3   93000.0      2      8
#
#       fea_7  fea_8  fea_9  fea_10      fea_11
# ...

# %%
df_cust["label"]
# Out:
# 0       1
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 1120    0
# 1121    0
# 1122    0
# 1123    0
# 1124    0
# Name: label, Length: 1125, dtype: int64

# %%
y=df_cust["label"] #y -> output
X=df_cust.drop(["label","id"],axis=1) #x-> input
X
# Out:
#       fea_1        fea_2  fea_3     fea_4  fea_5  fea_6  fea_7  fea_8  fea_9  \
# 0         5  1245.500000      3   77000.0      2     15      5    109      5
# 1         4  1277.000000      1  113000.0      2      8     -1    100      3
# 2         7  1298.000000      1  110000.0      2     11     -1    101      5
# 3         7  1335.500000      1  151000.0      2     11      5    110      3
# 4         7  1283.911373      2   59000.0      2     11      5    108      4
# ...     ...          ...    ...       ...    ...    ...    ...    ...    ...
# 1120      5  1289.000000      1  173000.0      2     15      5    112      3
# 1121      5  1283.911373      2   50000.0      2     15      5    108      4
# 1122      7  1220.000000      3   76000.0      2     11      2     90      5
# 1123      4  1250.000000      3  137000.0      2      8      5     90      5
# 1124      4  1415.000000      3   93000.0      2      8      5    113      4
#
#       fea_10      fea_11
# ...

# %%
from collections import Counter

# %%
Counter(y)
# Out:
# Counter({1: 225, 0: 900})

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
sampler=RandomOverSampler()
X_new, y_new=sampler.fit_resample(X,y)

# %%
Counter(y_new)
# Out:
# Counter({1: 900, 0: 900})

# %%
X_new.shape
# Out:
# (1800, 11)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X_new,y_new,test_size=0.2,random_state=42)
#her zaman model olusturulurken model train ve test olarak ıkıye bolunur

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
model=DecisionTreeClassifier()
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
print(f"Train set accurarcy score={accuracy_score(y_train,model.predict(X_train))}")
print(f"Test set accurarcy score={accuracy_score(y_test,model.predict(X_test))}")
# Out:
# Train set accurarcy score=1.0
# Test set accurarcy score=0.8944444444444445

# %%
tree.plot_tree(model)
# Out:
# [Text(0.49224713740458015, 0.9772727272727273, 'X[3] <= 79500.0\ngini = 0.5\nsamples = 1440\nvalue = [724, 716]'),
#  Text(0.22503180661577607, 0.9318181818181818, 'X[3] <= 61500.0\ngini = 0.45\nsamples = 567\nvalue = [194, 373]'),
#  Text(0.10941475826972011, 0.8863636363636364, 'X[10] <= 224.418\ngini = 0.396\nsamples = 331\nvalue = [90, 241]'),
#  Text(0.09669211195928754, 0.8409090909090909, 'X[9] <= 60002.0\ngini = 0.368\nsamples = 308\nvalue = [75, 233]'),
#  Text(0.0916030534351145, 0.7954545454545454, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.10178117048346055, 0.7954545454545454, 'X[10] <= 207.127\ngini = 0.361\nsamples = 305\nvalue = [72, 233]'),
#  Text(0.0916030534351145, 0.75, 'X[10] <= 200.12\ngini = 0.385\nsamples = 273\nvalue = [71, 202]'),
#  Text(0.08651399491094147, 0.7045454545454546, 'X[5] <= 15.5\ngini = 0.377\nsamples = 270\nvalue = [68, 202]'),
# ...

# %%
path=model.cost_complexity_pruning_path(X_train,y_train)
alphas=path["ccp_alphas"]

# %%
accuracy_train,accuracy_test=[],[]
for i in alphas:
    model_prune = DecisionTreeClassifier(ccp_alpha=i)
    
    model_prune.fit(X_train, y_train)
    y_train_pred = model_prune.predict(X_train)
    y_test_pred = model_prune.predict(X_test)
    
    accuracy_train.append(accuracy_score(y_train,y_train_pred))
    accuracy_test.append(accuracy_score(y_test,y_test_pred))

# %%
sns.lineplot(y=accuracy_train,x=alphas,label='Eğitim Doğruluğu')
sns.lineplot(y=accuracy_test,x=alphas,label='Test Doğruluğu')
plt.xlabel("Alfa Değerleri")
plt.ylabel("Doğruluk")
plt.xticks()
plt.show()

# %%
model_new=DecisionTreeClassifier(ccp_alpha=0.08)
model_new.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.08)

# %%
print(f"Train set accurarcy score={accuracy_score(y_train,model_new.predict(X_train))}")
print(f"Test set accurarcy score={accuracy_score(y_test,model_new.predict(X_test))}")
# Out:
# Train set accurarcy score=0.5027777777777778
# Test set accurarcy score=0.4888888888888889

# %%
tree.plot_tree(model_new)
# Out:
# [Text(0.5, 0.5, 'gini = 0.5\nsamples = 1440\nvalue = [724, 716]')]

# %%
sns.heatmap(confusion_matrix(y_test,model_new.predict(X_test)),
           annot=True,fmt="g") 
#tahminler ve dogru tahmin hakkında bu matrix bılgı verır
#dogru ve yanlıs tahmınlerı verır-> confusipn matrix(karmasıklık matrısı)
#0-1 -> yanlıs, 1-1 ve 0-0 dogru
# Out:
# <AxesSubplot:>

# %%
176+184 #toplam test seti
# Out:
# 360

# %%
176/360 #test seti basarı oranı
# Out:
# 0.4888888888888889
