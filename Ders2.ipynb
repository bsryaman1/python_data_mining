# %%
import pandas as pd

# %%
pd.read_csv("resources/nba.csv")
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
nba=pd.read_csv("resources/nba.csv")

# %%
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba.tail()
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0  Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %%
nba.index
# Out:
# RangeIndex(start=0, stop=458, step=1)

# %%
nba.values
# Out:
# array([['Avery Bradley', 'Boston Celtics', 0.0, ..., 180.0, 'Texas',
#         7730337.0],
#        ['Jae Crowder', 'Boston Celtics', 99.0, ..., 235.0, 'Marquette',
#         6796117.0],
#        ['John Holland', 'Boston Celtics', 30.0, ..., 205.0,
#         'Boston University', nan],
#        ...,
#        ['Tibor Pleiss', 'Utah Jazz', 21.0, ..., 256.0, nan, 2900000.0],
#        ['Jeff Withey', 'Utah Jazz', 24.0, ..., 231.0, 'Kansas', 947276.0],
#        [nan, nan, nan, ..., nan, nan, nan]], dtype=object)

# %%
nba.shape #tuple olarak dondurur. ilk elelman satır ikincisi sutun verir.
# Out:
# (458, 9)

# %%
nba.dtypes #her bır alanın ısmı ve hangı tıpte bilgi saklar verir.
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
nba.columns #columns ların ısmını verır.
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
nba.axes # x vey y olarak ıkı tane. x numarasını y adını tutar.
# Out:
# [RangeIndex(start=0, stop=458, step=1),
#  Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#         'College', 'Salary'],
#        dtype='object')]

# %%
nba.info #bos ve dolu bilgileri verır. eger bır alan bos verı ıcerısıyorsa ve 
#sayısal verı varsa o alan mutlaka float olarak saklanır.
# Out:
# <bound method DataFrame.info of               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# ...

# %%
revenue=pd.read_csv("resources/revenue.csv",index_col="Date") #index_col ile hangı alanın ındex olarak secılecegı belırlenır.

# %%
revenue
# Out:
#          New York  Los Angeles  Miami
# Date
# 1/1/16        985          122    499
# 1/2/16        738          788    534
# 1/3/16         14           20    933
# 1/4/16        730          904    885
# 1/5/16        114           71    253
# 1/6/16        936          502    497
# 1/7/16        123          996    115
# 1/8/16        935          492    886
# 1/9/16        846          954    823
# 1/10/16        54          285    216

# %%
revenue.sum() 
revenue.sum(axis=0)
revenue.sum(axis="index")
# 3 ude sutun bazında toplama ıslemı yapar.
# Out:
# New York       5475
# Los Angeles    5134
# Miami          5641
# dtype: int64

# %%
revenue["New York"].sum() #tek bır alanı toplar
# Out:
# 5475

# %%
revenue.sum(1)
revenue.sum(axis="columns")
#satır bazında toplama yapar.
# Out:
# Date
# 1/1/16     1606
# 1/2/16     2060
# 1/3/16      967
# 1/4/16     2519
# 1/5/16      438
# 1/6/16     1935
# 1/7/16     1234
# 1/8/16     2313
# 1/9/16     2623
# 1/10/16     555
# dtype: int64

# %%
nba.Name #name alanını getırır.
# Out:
# 0      Avery Bradley
# 1        Jae Crowder
# 2       John Holland
# 3        R.J. Hunter
# 4      Jonas Jerebko
#            ...
# 453     Shelvin Mack
# 454        Raul Neto
# 455     Tibor Pleiss
# 456      Jeff Withey
# 457              NaN
# Name: Name, Length: 458, dtype: object

# %%
nba.Number
# Out:
# 0       0.0
# 1      99.0
# 2      30.0
# 3      28.0
# 4       8.0
#        ...
# 453     8.0
# 454    25.0
# 455    21.0
# 456    24.0
# 457     NaN
# Name: Number, Length: 458, dtype: float64

# %%
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
nba.Position
# Out:
# 0       PG
# 1       SF
# 2       SG
# 3       SG
# 4       PF
#       ...
# 453     PG
# 454     PG
# 455      C
# 456      C
# 457    NaN
# Name: Position, Length: 458, dtype: object

# %% [markdown]
# Alan isminde boşluk varsa birleşik yazıcaksın.

# %%
nba.FirstName
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_43561/143359374.py in <module>
# ----> 1 nba.FirstName
#
# /usr/lib/python3/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'FirstName'

# %% [markdown]
# Boyle bır alan yok demek.

# %%
nba["First Name"] #bosluk varsa boyle de aranabılır.

# %% [markdown]
# Yıne boyle bır alan yok dedı. KeyError verdı.

# %%
nba["Name"].head().values #serıye dondturlen valuları lıste olarak aktar.
# Out:
# array(['Avery Bradley', 'Jae Crowder', 'John Holland', 'R.J. Hunter',
#        'Jonas Jerebko'], dtype=object)

# %%
nba[["Name","Salary","Position"]] #ıstedıgın kadar alanı ceker. Buyuk kucuk harf uyumuna dıkkat et.

# %%
selected_columns=["Position","Age"]
nba[selected_columns]
# Out:
#     Position   Age
# 0         PG  25.0
# 1         SF  25.0
# 2         SG  27.0
# 3         SG  22.0
# 4         PF  29.0
# ..       ...   ...
# 453       PG  26.0
# 454       PG  24.0
# 455        C  26.0
# 456        C  26.0
# 457      NaN   NaN
#
# [458 rows x 2 columns]

# %%
nba["Sports"]="Basketball" #yeni column ekler.
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary      Sports
# ...

# %%
nba["League"]="National Basketball Association"
nba

# %%
nba.insert(loc=4,column="Deneme",value="Değer") #4.indexe Deneme diye column ekler ve hepsının degerini Değer yapar.

# %%
nba

# %% [markdown]
# # Varolan Columndan Yeni Bir Column Oluşturma

# %%
nba["New_Age"]=nba["Age"].add(15) #age kısmına 15 ekler.

# %%
nba

# %%
nba["Weight.kg"]=nba["Weight"]*0.4535 #pound tutunden kilograma cevırdı ve yenı degerı yazdırdı.

# %%
nba

# %%
nba["Weight.kg"]=nba["Weight"].mul(0.4535) #aynı ıslem mul ıle de yapılabılır.

# %%
nba

# %%
nba["Position"].value_counts(ascending=True,normalize=True)*100 #unique degerlerı verır. 
#100 desını kucukten buyuge sıralı verır.

# %%
nba.dropna(how="any") #boş alanların hepsını satır olarak sıler.
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7     Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#            College     Salary      Sports
# 0            Texas  7730337.0  Basketball
# ...

# %%
nba.dropna(how="all") #sadece butun alanları bos olan kayıtları sıler.
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary      Sports
# ...

# %%
nba.dropna(subset=["College"]) #sadece college alanı bos olan kayıtları sıler.

# %%
nba.dropna(subset=["College","Salary"]) #hem college hem salary ıcın bos olan alanları sıler.
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7     Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#            College     Salary      Sports
# 0            Texas  7730337.0  Basketball
# ...

# %%
nba.fillna(0) #bos alanları doldurmaya yarar. Butun bos alanları 0 ile doldurur.

# %%
nba["College"].fillna("Belirsiz", inplace=True) # College alanındakı boslukları Belirsiz ile doldurdur.
#inplace ile kalıcı hale getırdı. Yoksa Ram de kalır ve gerı sılınır.

# %%
nba

# %%
nba=pd.read_csv("resources/nba.csv").dropna(how="all")
nba.tail()

# %%
nba["Age"].hasnans #boş alan var mı kontrol eder.

# %%
nba["Age"].astype("int")
nba["Age"].astype(int)
#ikisi de tur donusumu yapar. Tur donusumu yaparken bos alan olmamasına dıkkat et.
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# /tmp/ipykernel_43561/65343128.py in <module>
# ----> 1 nba["Age"].astype("int")
#       2 nba["Age"].astype(int)
#       3 #ikisi de tur donusumu yapar. Tur donusumu yaparken bos alan olmamasına dıkkat et.
#
# /usr/lib/python3/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# /usr/lib/python3/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# ...

# %%
nba["Age"]=nba["Age"].astype("int") #tur donusumu bu alan uzerınde uygulanır.
nba
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# /tmp/ipykernel_43561/2945825299.py in <module>
# ----> 1 nba["Age"]=nba["Age"].astype("int") #tur donusumu bu alan uzerınde uygulanır.
#       2 nba
#
# /usr/lib/python3/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# /usr/lib/python3/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
# ...

# %%
nba["Salary"].hasnans
# Out:
# True

# %%
nba["Salary"].astype(int) # bos alan oldugu ıcın hata verır.

# %%
nba["Salary"]=nba["Salary"].fillna(0)
nba["Salary"].astype(int)

# %%
nba["Position"].unique() #kaç farklı POisition var

# %%
nba["Position"].nunique()

# %%
nba["Position"]=nba["Position"].astype("category") #kategorı verıpıne cevırıp bellekten tasarruf saglar.
nba.info()

# %%
nba.sort_values(by="Name") #Name e gore sıralar. A dan Z ye dogru

# %%
nba.sort_values(by=["Name", "Salary"]) #ilk Name e gore sonra bunları da kendı arasında Salary e gore sıralar.

# %%
nba.sort_values(by=["Team","Name"],ascending=[True,False]) #Team a gore A dan Zye Name gore Z den Aya

# %%
nba.sort_values("Salary", na_position="first")
#bosları onde sıralar.
# Out:
#                 Name                 Team  Number Position   Age Height  \
# 2       John Holland       Boston Celtics    30.0       SG  27.0    6-5
# 46       Elton Brand   Philadelphia 76ers    42.0       PF  37.0    6-9
# 171    Dahntay Jones  Cleveland Cavaliers    30.0       SG  35.0    6-6
# 264    Jordan Farmar    Memphis Grizzlies     4.0       PG  29.0    6-2
# 269     Ray McCallum    Memphis Grizzlies     5.0       PG  24.0    6-3
# ..               ...                  ...     ...      ...   ...    ...
# 339       Chris Bosh           Miami Heat     1.0       PF  32.0   6-11
# 251    Dwight Howard      Houston Rockets    12.0        C  30.0   6-11
# 33   Carmelo Anthony      New York Knicks     7.0       SF  32.0    6-8
# 169     LeBron James  Cleveland Cavaliers    23.0       SF  31.0    6-8
# 109      Kobe Bryant   Los Angeles Lakers    24.0       SF  37.0    6-6
#
#      Weight            College      Salary      Sports
# ...

# %%
nba.sort_index(inplace=True) #geri orijinal halıne getırır.
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary      Sports
# ...

# %% [markdown]
# # Rank Metodu

# %%
nba["Salary"].rank() #salarye gore kucukten buyuge sıralar
# Out:
# 0      350.0
# 1      337.0
# 2        NaN
# 3      125.0
# 4      300.0
#        ...
# 453    206.0
# 454     64.0
# 455    232.5
# 456     80.0
# 457      NaN
# Name: Salary, Length: 458, dtype: float64

# %%
nba.sort_values("Salary",ascending=False) #kayıtları Ranke gore sıralar. Aynı olanlara aynı rank i verir.

# %%
nba.sort_index(inplace=True) #index sıralamasını eski haline getirir.
nba
nba["Age"].fillna(0)
nba["Age"]

# %%
nba["Salary"].rank() #küçükten büyüğe rank salarye göre sıralar.

# %%
nba["Salary Rank"]=nba["Salary"].rank(ascending=False)
nba
#Salary si buyukten kucuge olarak Salary Rank ları sıralar
